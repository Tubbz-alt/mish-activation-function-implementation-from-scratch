# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansai26/mish-activation-function-implementation-from-scratch/blob/master/mish_activation_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MISH activation function**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# implementation

# %%
import numpy as np

# %%
def mish(x):
  return x*np.tanh(np.log(1+np.exp(x)))

# %%
from matplotlib import pyplot

#mish activation function

def mish(x):
  return x*np.tanh(np.log(1+np.exp(x)))

# define a series of inputs
series_in = [x for x in range(-10, 11)]
# calculate outputs for our inputs
series_out = [mish(x) for x in series_in]
# line plot of raw inputs to rectified outputs
pyplot.plot(series_in, series_out)
pyplot.show()
